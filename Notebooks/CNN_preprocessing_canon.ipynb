# %%
import os
import glob
import re
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import shutil
import random
# %matplotlib inline

# %% [markdown]
# ### configure your aws credentials to get writerights on S3

# %% [raw]
# $ aws configure
# AWS Access Key ID [None]: ??
# AWS Secret Access Key [None]: ??
# Default region name [None]:
# Default output format [None]:

# %%
home = os.getcwd().split('AUT-CNN-TUB')[0]

# %% [markdown]
# # Image cerntering

# %%
def get_all_images_from_part(read_path, partname, extension):

    numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
    pats_path = [x.string for x in numbers if x is not None]

    if pats_path == []:
        print('ERROR: no directoris in path or wrong naming')
        SystemExit
        
    if partname not in pats_path:
        if type(partname) is str:
            print("ERROR: dir for this partnumber doesn't exists" )
            SystemExit
        else:
            partname = str(partname)
            
            if partname not in pats_path:
                print("ERROR: dir for this partnumber doesn't exists")
                SystemExit
                
    if extension  not in ['gif', 'jpeg', 'jpg', 'png', 'JPG']:
        print('ERROR: unknown extension')
        SystemExit
        
    else:
        data_path = os.path.join(os.path.join(read_path, partname), '*{}'.format(extension))
        files = glob.glob(data_path)
        return files

# %%
read_path = os.path.join(home,'AUT-CNN-TUB/Data/Raw_Data_27072018_canon/')

# %%
numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
[x.string for x in numbers if x is not None]
# Out:
# ['2',
#  '13',
#  '14',
#  '1',
#  '7.1',
#  '8',
#  '5',
#  '4',
#  '3',
#  '10',
#  '12',
#  '11',
#  '6',
#  '7.2',
#  '15',
#  '9']

# %%
files = get_all_images_from_part(read_path, 1, 'jpg')

# %%
for z,i in enumerate(files):
    if '5396.' in i:
        print(i, z)

# %%
file_path = files[7]
img_name = file_path.split('/')[-1]  
image = cv2.imread(file_path)

# %% [markdown]
# ### original

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#ax2 = fig.add_subplot(1, 2, 2)
#ax2.axis('off')
#ax2.set_title('Gaussian interpolation:\n' + file_path.split('/')[-1])
#ax2.imshow(image, cmap='gray', interpolation="gaussian");
plt.show()

# %% [markdown]
# ### find sector

# %%
w, h, c = image.shape
image_copy = image.copy()
cv2.circle(image_copy,(int(h/2), int(w/2)),460,(0,255,0),2)
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(image_copy, cmap='gray');
#ax2 = fig.add_subplot(1, 2, 2)
#ax2.axis('off')
#ax2.set_title('Gaussian interpolation:\n' + file_path.split('/')[-1])
#ax2.imshow(image, cmap='gray', interpolation="gaussian");
plt.show()

# %% [raw]
# w, h, _ = image.shape
# scale = 0.85
# image =image[int((w-w*scale)/2): int((w-w*scale)/2+w*scale), int((h-h*scale)/2):int((h-h*scale)/2+h*scale)]
# plt.imshow(image)
# plt.show()

# %% [raw]
# w, h, c = image.shape
#
# a, b = w/2, h/2
# r = 350
# fig = plt.figure(figsize=(20,20))
# ax1 = fig.add_subplot(1, 2, 1)
# y,x = np.ogrid[-a:w-a, -b:h-b]
# mask = x*x + y*y >= r*r
# image[mask] = 255
# ax1.matshow(image[:,:,0], cmap='gray')
# plt.show()

# %% [markdown]
# ### blurred

# %%
blurred = cv2.bilateralFilter(image,10, 100, 100)

fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(blurred)
plt.show()

# %% [markdown]
# ### grayscale

# %%
imgray = cv2.cvtColor(blurred,cv2.COLOR_BGR2GRAY)

fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(imgray, cmap='gray');
plt.show()

# %%
thresh = cv2.Canny(blurred,50,10)

fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(thresh, cmap='gray');
plt.show()

# %% [markdown]
# ### findContours

# %%
_,contours,_ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cnt = contours
contour_indexer = 0
i = 0
filteredContours = []
for c in cnt:
    if len(c) > 20:
        filteredContours.append(c)
    if len(filteredContours) > 0:
        merged_contours = np.concatenate(filteredContours)
    else:
        merged_contours = None

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(cv2.drawContours(image, merged_contours, -1, (255,255,255), 3), cmap='gray');
plt.show()

# %% [markdown]
# ### fit in circle, to know where to cut

# %%
(x,y),radius = cv2.minEnclosingCircle(merged_contours)
center = (int(x),int(y))
radius = int(radius)
img = cv2.circle(image,center,radius,(0,255,0),2)

fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(img)
plt.show()

# %%
scale = 1.1
scaled_rad = radius * scale
try:
    img_cutted = image[center[1] - scaled_rad : center[1] + scaled_rad,
                       center[0] - scaled_rad : center[0] + scaled_rad,
                       : ] 
except:
    img_cutted = image[center[1] - radius : center[1] + radius,
                       center[0] - radius : center[0] + radius,
                       : ] 
    
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(1, 2, 1)
ax1.axis('off')
ax1.set_title(file_path.split('/')[-1])
ax1.imshow(img_cutted)
plt.show()

# %%
def get_part_from_image(image, scale = 1.1):
    
    #w, h, c = image.shape

    #a, b = w/2, h/2
    #r = 350
    #y,x = np.ogrid[-a:w-a, -b:h-b]
    #mask = x*x + y*y >= r*r
    #image[mask] = 255
    
    #w, h, _ = image.shape
    #size = 600

    #image =image[int((w-size)/2): int((w-size)/2+size), int((h-size)/2):int((h-size)/2+size)]
    
    blurred = cv2.bilateralFilter(image,10, 100, 100)
    imgray = cv2.cvtColor(blurred,cv2.COLOR_BGR2GRAY)
    thresh = cv2.Canny(blurred,50,10)
    _,contours,_ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    
    
    cnt = contours
    contour_indexer = 0
    i = 0
    filteredContours = []
    for c in cnt:
        if len(c) > 30:
            filteredContours.append(c)
    if len(filteredContours) > 0:
        merged_contours = np.concatenate(filteredContours)

        (x,y),radius = cv2.minEnclosingCircle(merged_contours)
        center = (int(x),int(y))
        radius = int(radius)
        scaled_rad = int(radius * scale)
        try:
            img_cutted = image[center[1] - scaled_rad : center[1] + scaled_rad,
                               center[0] - scaled_rad : center[0] + scaled_rad,
                               : ] 
        except:
            img_cutted = image[center[1] - radius : center[1] + radius,
                               center[0] - radius : center[0] + radius,
                               : ] 

        return img_cutted
    else:
        return None

# %%
files = get_all_images_from_part(read_path, 2, 'jpg')
for i, file_path in enumerate(files[:10]):
    image = cv2.imread(file_path)
    print(i,file_path)
    try:
        plt.imshow(get_part_from_image(image))
        #plt.imshow(cv2.drawContours(image, get_part_from_image(image, scale = 1.1), -1, (255,255,255), 3), cmap='gray')
        plt.show()  
    except:
        print('ERROR')
# Out:
# 0 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4070.jpg
# 1 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4155.jpg
# 2 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.3640.jpg
# 3 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4088.jpg
# 4 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.3625.jpg
# 5 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4133.jpg
# 6 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.3646.jpg
# 7 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4089.jpg
# 8 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4108.jpg
# 9 /home/jeronimo/git/AUT-CNN-TUB/Data/Raw_Data_27072018_canon/2/02.0.2.3.4081.jpg

# %%
get_part_from_image(image).var()
# Out:
# 848.7544069468131

# %% [markdown]
# ### genrate folder whith cerndered and well shaped images

# %%
new_size = 200

home = os.getcwd().split('AUT-CNN-TUB')[0]
read_path = os.path.join(home,'AUT-CNN-TUB/Data/Raw_Data_27072018_canon/')
write_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_{}x{}/'.format(new_size, new_size))

extension = 'jpg'

numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])

for part_nr in [x.string for x in numbers if x is not None]:
    for file_path in get_all_images_from_part(read_path, part_nr, extension):
        img_name = file_path.split('/')[-1].replace('.jpg','')
        image = cv2.imread(file_path)

        img_centerd = get_part_from_image(image)
        if img_centerd is not None:
            try:
                img_resized = cv2.resize(img_centerd,(new_size, new_size))
            except:
                print('Image {}.jpg is to small.'.format(img_name))
                img_resized = None
                
            part_patch =os.path.join(write_path, part_nr)
            
            if img_resized is not None:
                if img_resized.var() > 500:
                    if os.path.exists(part_patch):
                        cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)
                    else:
                        os.makedirs(part_patch)
                        cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)
                else:
                    print('Image {}.jpg does not have the necessary variance.'.format(img_name))
# Out:
# Image 02.0.2.3.4133.jpg does not have the necessary variance.
# Image 02.0.2.3.4108.jpg does not have the necessary variance.
# Image 02.0.2.3.4149.jpg does not have the necessary variance.
# Image 02.0.2.3.4142.jpg does not have the necessary variance.
# Image 02.0.2.3.4111.jpg does not have the necessary variance.
# Image 02.0.2.3.4103.jpg does not have the necessary variance.
# Image 02.0.2.3.4115.jpg does not have the necessary variance.
# Image 02.0.2.3.3665.jpg does not have the necessary variance.
# Image 02.0.2.3.4105.jpg does not have the necessary variance.
# Image 02.0.2.3.3630.jpg is to small.
# Image 02.0.2.3.4118.jpg does not have the necessary variance.
# Image 02.0.2.3.4127.jpg does not have the necessary variance.
# Image 02.0.2.3.4124.jpg does not have the necessary variance.
# Image 02.0.2.3.4143.jpg does not have the necessary variance.
# Image 02.0.2.3.4129.jpg does not have the necessary variance.
# Image 02.0.2.3.4148.jpg does not have the necessary variance.
# Image 02.0.2.3.3669.jpg does not have the necessary variance.
# Image 02.0.2.3.4110.jpg does not have the necessary variance.
# Image 02.0.2.3.4131.jpg does not have the necessary variance.
# Image 02.0.2.3.4114.jpg does not have the necessary variance.
# Image 02.0.2.3.3661.jpg is to small.
# Image 02.0.2.3.4132.jpg does not have the necessary variance.
# Image 02.0.2.3.4146.jpg does not have the necessary variance.
# Image 02.0.2.3.4125.jpg does not have the necessary variance.
# Image 02.0.2.3.4145.jpg does not have the necessary variance.
# Image 02.0.2.3.4102.jpg does not have the necessary variance.
# Image 02.0.2.3.4119.jpg does not have the necessary variance.
# Image 02.0.2.3.4107.jpg does not have the necessary variance.
# Image 02.0.2.3.4112.jpg does not have the necessary variance.
# Image 02.0.2.3.4109.jpg does not have the necessary variance.
# Image 02.0.2.3.4126.jpg does not have the necessary variance.
# Image 02.0.2.3.4152.jpg does not have the necessary variance.
# Image 02.0.2.3.4104.jpg does not have the necessary variance.
# Image 02.0.2.3.4121.jpg does not have the necessary variance.
# Image 02.0.2.3.4116.jpg does not have the necessary variance.
# Image 02.0.2.3.4106.jpg does not have the necessary variance.
# Image 02.0.2.3.4147.jpg does not have the necessary variance.
# Image 02.0.2.3.4150.jpg does not have the necessary variance.
# Image 02.0.2.3.4130.jpg does not have the necessary variance.
# Image 02.0.2.3.4144.jpg does not have the necessary variance.
# Image 02.0.2.3.4120.jpg does not have the necessary variance.
# Image 02.0.2.3.4117.jpg does not have the necessary variance.
# Image 02.0.2.3.4151.jpg does not have the necessary variance.
# Image 02.0.2.3.3671.jpg does not have the necessary variance.
# Image 02.0.2.3.4128.jpg does not have the necessary variance.
# Image 13.0.2.3.5038.jpg is to small.
# Image 13.0.2.3.5035.jpg is to small.
# Image 13.0.2.3.5036.jpg is to small.
# Image 14.0.2.3.3398.jpg is to small.
# Image 14.0.2.3.5199.jpg is to small.
# Image 14.0.2.3.3403.jpg is to small.
# Image 14.0.2.3.3391.jpg is to small.
# Image 14.0.2.3.3382.jpg is to small.
# Image 14.0.2.3.3386.jpg is to small.
# Image 14.0.2.3.3402.jpg is to small.
# Image 14.0.2.3.3383.jpg is to small.
# Image 14.0.2.3.3387.jpg is to small.
# Image 14.0.2.3.3379.jpg is to small.
# Image 14.0.2.3.3384.jpg is to small.
# Image 14.0.2.3.3363.jpg is to small.
# Image 01.0.2.3.3589.jpg is to small.
# Image 01.0.2.3.4050.jpg is to small.
# Image 01.0.2.3.3587.jpg does not have the necessary variance.
# Image 01.0.2.3.3947.jpg is to small.
# Image 01.0.2.3.3592.jpg is to small.
# Image 01.0.2.3.4036.jpg is to small.
# Image 01.0.2.3.3591.jpg is to small.
# Image 01.0.2.3.3948.jpg is to small.
# Image 01.0.2.3.3590.jpg is to small.
# Image 07.1.2.3.3857.jpg does not have the necessary variance.
# Image 07.1.2.3.3876.jpg does not have the necessary variance.
# Image 07.1.2.3.3856.jpg does not have the necessary variance.
# Image 07.1.2.3.3894.jpg does not have the necessary variance.
# Image 07.1.2.3.3877.jpg does not have the necessary variance.
# Image 07.1.2.3.3858.jpg is to small.
# Image 07.1.2.3.3895.jpg does not have the necessary variance.
# Image 08.0.2.3.4609.jpg is to small.
# Image 05.0.2.3.4327.jpg does not have the necessary variance.
# Image 05.0.2.3.2947.jpg does not have the necessary variance.
# Image 05.0.2.3.2984.jpg does not have the necessary variance.
# Image 05.0.2.3.2970.jpg does not have the necessary variance.
# Image 05.0.2.3.2966.jpg does not have the necessary variance.
# Image 05.0.2.3.2990.jpg does not have the necessary variance.
# Image 05.0.2.3.2945.jpg does not have the necessary variance.
# Image 05.0.2.3.2944.jpg is to small.
# Image 05.0.2.3.3001.jpg does not have the necessary variance.
# Image 05.0.2.3.3022.jpg is to small.
# Image 05.0.2.3.2976.jpg does not have the necessary variance.
# Image 05.0.2.3.2989.jpg does not have the necessary variance.
# Image 05.0.2.3.3020.jpg is to small.
# Image 05.0.2.3.2979.jpg does not have the necessary variance.
# Image 05.0.2.3.2955.jpg does not have the necessary variance.
# Image 05.0.2.3.2971.jpg does not have the necessary variance.
# Image 05.0.2.3.4330.jpg is to small.
# Image 05.0.2.3.2996.jpg does not have the necessary variance.
# Image 05.0.2.3.2977.jpg does not have the necessary variance.
# Image 04.0.2.3.4289.jpg is to small.
# Image 04.0.2.3.4248.jpg is to small.
# Image 03.0.2.3.3730.jpg is to small.
# Image 03.0.2.3.3734.jpg is to small.
# Image 03.0.2.3.3750.jpg is to small.
# Image 03.0.2.3.4203.jpg is to small.
# Image 03.0.2.3.4229.jpg does not have the necessary variance.
# Image 03.0.2.3.3733.jpg is to small.
# Image 03.0.2.3.3744.jpg is to small.
# Image 03.0.2.3.3720.jpg is to small.
# Image 03.0.2.3.4201.jpg is to small.
# Image 03.0.2.3.3718.jpg is to small.
# Image 03.0.2.3.4200.jpg does not have the necessary variance.
# Image 03.0.2.3.4230.jpg does not have the necessary variance.
# Image 06.0.2.3.4367.jpg is to small.
# Image 06.0.2.3.4365.jpg is to small.
# Image 06.0.2.3.3819.jpg is to small.
# Image 06.0.2.3.3823.jpg is to small.
# Image 06.0.2.3.4381.jpg is to small.
# Image 06.0.2.3.3818.jpg is to small.
# Image 06.0.2.3.3817.jpg is to small.
# Image 06.0.2.3.4380.jpg is to small.
# Image 06.0.2.3.4364.jpg is to small.
# Image 06.0.2.3.3815.jpg does not have the necessary variance.
# Image 06.0.2.3.3836.jpg does not have the necessary variance.
# Image 06.0.2.3.3834.jpg does not have the necessary variance.
# Image 06.0.2.3.3835.jpg does not have the necessary variance.
# Image 06.0.2.3.3814.jpg does not have the necessary variance.
# Image 06.0.2.3.3816.jpg does not have the necessary variance.
# Image 06.0.2.3.3822.jpg is to small.
# Image 06.0.2.3.4363.jpg is to small.
# Image 06.0.2.3.3820.jpg is to small.
# Image 06.0.2.3.3821.jpg is to small.
# Image 07.2.2.3.3940.jpg does not have the necessary variance.
# Image 09.0.2.3.4674.jpg is to small.
# Image 09.0.2.3.4673.jpg does not have the necessary variance.

# %% [markdown]
# ### downscale

# %%
new_size = 100

home = os.getcwd().split('AUT-CNN-TUB')[0]
read_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_200x200/')
write_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_{}x{}/'.format(new_size, new_size))

extension = 'jpg'

numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
for part_nr in [x.string for x in numbers if x is not None]:
    for file_path in get_all_images_from_part(read_path, part_nr, extension):
        img_name = file_path.split('/')[-1].replace('.jpg','')
        image = cv2.imread(file_path)

        try:
            img_resized = cv2.resize(image,(new_size, new_size))
        except:
            print('Image {}.jpg is to small.'.format(img_name))
        
        part_patch =os.path.join(write_path, part_nr)
            
        if os.path.exists(part_patch):
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)
        else:
            os.makedirs(part_patch)
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)

# %%
new_size = 50

home = os.getcwd().split('AUT-CNN-TUB')[0]
read_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_200x200/')
write_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_{}x{}/'.format(new_size, new_size))

extension = 'jpg'

numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
for part_nr in [x.string for x in numbers if x is not None]:
    for file_path in get_all_images_from_part(read_path, part_nr, extension):
        img_name = file_path.split('/')[-1].replace('.jpg','')
        image = cv2.imread(file_path)

        try:
            img_resized = cv2.resize(image,(new_size, new_size))
        except:
            print('Image {}.jpg is to small.'.format(img_name))
        
        part_patch =os.path.join(write_path, part_nr)
            
        if os.path.exists(part_patch):
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)
        else:
            os.makedirs(part_patch)
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)

# %%
new_size = 28

home = os.getcwd().split('AUT-CNN-TUB')[0]
read_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018//27072018_canon_centered_200x200/')
write_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_{}x{}/'.format(new_size, new_size))

extension = 'jpg'

numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
for part_nr in [x.string for x in numbers if x is not None]:
    for file_path in get_all_images_from_part(read_path, part_nr, extension):
        img_name = file_path.split('/')[-1].replace('.jpg','')
        image = cv2.imread(file_path)

        try:
            img_resized = cv2.resize(image,(new_size, new_size))
        except:
            print('Image {}.jpg is to small.'.format(img_name))
        
        part_patch =os.path.join(write_path, part_nr)
            
        if os.path.exists(part_patch):
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)
        else:
            os.makedirs(part_patch)
            cv2.imwrite(os.path.join(part_patch, '{}.{}'.format(img_name, extension)), img_resized)

# %% [markdown]
# ### summarize

# %%
read_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_canon_centered_28x28/')

numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
print('Images in File:')
for part_nr in [x.string for x in numbers if x is not None]:
    print('{}\t{}'.format(len(os.listdir(os.path.join(read_path, part_nr))), part_nr))
# Out:
# Images in File:
# 143	2
# 154	13
# 166	14
# 195	1
# 134	7.1
# 143	8
# 104	5
# 118	4
# 112	3
# 148	10
# 165	12
# 155	11
# 52	6
# 122	7.2
# 164	15
# 148	9

# %%
size = 200

read_path = os.path.join(home,'AUT-CNN-TUB/Data/27072018/27072018_industry_centered_{}x{}/'.format(size, size))
path_length   = len(read_path) 
test_path  = os.path.join(home,'AUT-CNN-TUB/Data/TF_Images_industry_{}/test/'.format(size, size))
train_path = os.path.join(home,'AUT-CNN-TUB/Data/TF_Images_industry_{}/train/'.format(size, size))

ratio=0.7
img_path=read_path
GRBtoGray = False
extension = 'jpg'


numbers = filter(None, [re.match('\d+',f) for f in  os.listdir(read_path)])
for part_nr in [x.string for x in numbers if x is not None]:
    
    files = get_all_images_from_part(read_path, part_nr, extension)            
    num_imag     = len(files)
    breakpoint   = int(np.round(ratio*num_imag)) 
    Data         = np.arange(0,num_imag)            
    random.shuffle(Data)  
    DataTrain    = Data[:breakpoint]              
    DataTest     = Data[breakpoint:]              
    
    if os.path.exists(test_path) is False:
        os.makedirs(test_path)
        
    if os.path.exists(train_path) is False:
        os.makedirs(train_path)
    
    for i,f1 in enumerate(files):
        img_name = f1.split('/')[-1]        

        img = cv2.imread(f1)
        if(GRBtoGray == True):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)      


        if(i in DataTrain):
            cv2.imwrite(train_path + img_name, img)  
        if(i in DataTest):
            cv2.imwrite(test_path + img_name, img)

# %% [markdown]
# ### save zip on S3

# %%
import boto3
import botocore

s3 = boto3.resource('s3')
bucket = s3.Bucket('imagesforcnn')

for bucket in s3.buckets.all():
    print(bucket.name)
        
for object in s3.Bucket('imagesforcnn').objects.all():
    print(object)

# %%
# zip dir 
from_dir = os.path.join(home,'AUT-CNN-TUB/Data/Centered/')
to_dir = os.path.join(home,'AUT-CNN-TUB/Data/Centered')

shutil.make_archive(to_dir,
                    'zip',
                    from_dir
                    )

# %% [raw]
# # Upload a new file
# data = open(os.path.join(home,'AUT-CNN-TUB/Data/Centered_100x100/1/001010001.jpg') 'rb')
# s3.Bucket('imagesforcnn').put_object(Key='test.jpg', Body=data)

# %%
path = os.path.join(home,'AUT-CNN-TUB/Data/')

from_dir = os.path.join(home,'AUT-CNN-TUB/Data/Centered')
to_dir = os.path.join(home,'AUT-CNN-TUB/Data/')
filename = 'Centered'

extension = 'zip'

if extension is 'zip':
    shutil.make_archive(os.path.join(os.path.join(to_dir, filename)), extension, from_dir)

# Upload a new file
data = open(os.path.join(to_dir, filename + '.{}'.format(extension)), 'rb')
print('uploading {}.{} ... '.format(filename, extension), end='\r')
bucket.put_object(Key=filename + '.{}'.format(extension), Body=data)
print('uploading {}.{} finished'.format(filename, extension))
